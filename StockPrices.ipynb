100	NMDC LIMITED	NMDC
101	NTPC LIMITED	NTPC
102	OIL & NATURAL GAS CORPORATION LIMITED	ONGC
103	PAGE INDUSTRIES LIMITED	PAGEIND
104	PETRONET LNG LIMITED	PETRONET
105	PIDILITE INDUSTRIES LIMITED	PIDILITIND
106	PIRAMAL ENTERPRISES LIMITED	PEL
107	POWER FINANCE CORPORATION LIMITED	PFC
108	POWER GRID CORPORATION OF INDIA LIMITED	POWERGRID
109	PUNJAB NATIONAL BANK	PNB
110	PVR LIMITED	PVR
111	RBL BANK LIMITED	RBLBANK
112	RELIANCE INDUSTRIES LIMITED	RELIANCE
113	REC LIMITED	RECLTD
114	SHREE CEMENT LIMITED	SHREECEM
115	SHRIRAM TRANSPORT FINANCE COMPANY LIMITED	SRTRANSFIN
116	SIEMENS LIMITED	SIEMENS
117	SRF LIMITED	SRF
118	STATE BANK OF INDIA	SBIN
119	SBI LIFE INSURANCE COMPANY LIMITED	SBILIFE
120	STEEL AUTHORITY OF INDIA LIMITED	SAIL
121	SUN PHARMACEUTICAL INDUSTRIES LIMITED	SUNPHARMA
122	SUN TV NETWORK LIMITED	SUNTV
123	TATA CHEMICALS LIMITED	TATACHEM
124	TATA CONSULTANCY SERVICES LIMITED	TCS
125	TATA CONSUMER PRODUCTS LIMITED	TATACONSUM
126	TATA MOTORS LIMITED	TATAMOTORS
127	TATA POWER COMPANY LIMITED	TATAPOWER
128	TATA STEEL LIMITED	TATASTEEL
129	TECH MAHINDRA LIMITED	TECHM
130	THE RAMCO CEMENTS LIMITED	RAMCOCEM
131	TITAN COMPANY LIMITED	TITAN
132	TORRENT PHARMACEUTICALS LIMITED	TORNTPHARM
133	TORRENT POWER LIMITED	TORNTPOWER
134	TVS MOTOR COMPANY LIMITED	TVSMOTOR
135	UJJIVAN FINANCIAL SERVICES LIMITED	UJJIVAN
136	ULTRATECH CEMENT LIMITED	ULTRACEMCO
137	UNITED BREWERIES LIMITED	UBL
138	UNITED SPIRITS LIMITED	MCDOWELL-N
139	UPL LIMITED	UPL
140	VEDANTA LIMITED	VEDL
141	VOLTAS LIMITED	VOLTAS
142	WIPRO LIMITED	WIPRO
143	YES BANK LIMITED	YESBANK
144	ZEE ENTERTAINMENT ENTERPRISES LIMITED	ZEEL
'''
a = a.split('\n')
l = []
for i in range(len(a)):
    try:
        k = a[i].split('\t')
        l.append(k[2])
    except:
        continue
print(l)
# Out:
# ['NIFTYIT', 'BANKNIFTY', 'ACC', 'ADANIENT', 'ADANIPORTS', 'ADANIPOWER', 'AMARAJABAT', 'AMBUJACEM', 'APOLLOHOSP', 'APOLLOTYRE', 'ASHOKLEY', 'ASIANPAINT', 'AUROPHARMA', 'AXISBANK', 'BAJAJ-AUTO', 'BAJFINANCE', 'BAJAJFINSV', 'BALKRISIND', 'BANDHANBNK', 'BANKBARODA', 'BATAINDIA', 'BERGEPAINT', 'BEL', 'BHARATFORG', 'BPCL', 'BHARTIARTL', 'INFRATEL', 'BHEL', 'BIOCON', 'BOSCHLTD', 'BRITANNIA', 'CADILAHC', 'CANBK', 'CENTURYTEX', 'CESC', 'CHOLAFIN', 'CIPLA', 'COALINDIA', 'COLPAL', 'CONCOR', 'CUMMINSIND', 'DABUR', 'DIVISLAB', 'DLF', 'DRREDDY', 'EICHERMOT', 'EQUITAS', 'ESCORTS', 'EXIDEIND', 'FEDERALBNK', 'GAIL', 'GLENMARK', 'GMRINFRA', 'GODREJCP', 'GODREJPROP', 'GRASIM', 'HAVELLS', 'HCLTECH', 'HDFCBANK', 'HDFC', 'HDFCLIFE', 'HEROMOTOCO', 'HINDALCO', 'HINDPETRO', 'HINDUNILVR', 'ICICIBANK', 'ICICIPRULI', 'NAUKRI', 'IDEA', 'IDFCFIRSTB', 'IBULHSGFIN', 'IOC', 'IGL', 'INDUSINDBK', 'INFY', 'INDIGO', 'ITC', 'JINDALSTEL', 'JSWSTEEL', 'JUBLFOOD', 'JUSTDIAL', 'KOTAKBANK', 'L&TFH', 'LT', 'LICHSGFIN', 'LUPIN'
# ...

# %%
len(l)
# Out:
# 146

# %%
# from nsepy import get_history, get_index_pe_history
# from datetime import date
# import pandas as pd
# data = get_history(symbol="ADANIPORTS", start=date(2015,1,1), end=date(2015,1,31))
# data[['Close']].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
from nsepy import get_history, get_index_pe_history
from datetime import date
import pandas as pd
k = []
for i in l:
    try:
        data = get_history(symbol=i, start=date(2000,1,1), end=date(2020,12,31))
        data.to_excel(i+'.xlsx')
    except:
        k.appned(i)
# Out:
# Exception in thread Thread-9840:
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/urllib3/connection.py", line 159, in _new_conn
#     conn = connection.create_connection(
#   File "/usr/lib/python3/dist-packages/urllib3/util/connection.py", line 84, in create_connection
#     raise err
#   File "/usr/lib/python3/dist-packages/urllib3/util/connection.py", line 74, in create_connection
#     sock.connect(sa)
# TimeoutError: [Errno 110] Connection timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/urllib3/connectionpool.py", line 665, in urlopen
#     httplib_response = self._make_request(
#   File "/usr/lib/python3/dist-packages/urllib3/connectionpool.py", line 376, in _make_request
#     self._validate_conn(conn)
#   File "/usr/lib/python3/dist-packages/urllib3/connectionpool.py", line 996, in _validate_conn
#     conn.connect()
# ...

# %%
k
# Out:
# []

# %%
from os import listdir
from os.path import isfile, join
onlyfiles = [f for f in listdir()]

# %%
dff = pd.DataFrame()
for i in onlyfiles:
    if '.xlsx' in i:
        df = pd.read_excel(i,engine='openpyxl')
        df['File']=i
        dff = pd.concat([dff,df])

# %%
df = pd.read_excel('ACC.xlsx',engine='openpyxl')

# %%
dff.to_excel('AllStockData.xlsx')
